# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/ml project/movies_dataset_filled.csv'

# %%
import pandas as pd
df = pd.read_csv(file_path)

# %%
df.columns
# Out:
# Index(['title', 'original_language', 'original_title', 'overview', 'genres',
#        'production_companies', 'production_countries', 'imdb_rating',
#        'director'],
#       dtype='object')

# %%
df.shape
# Out:
# (1039268, 9)

# %%
df.head(10)
# Out:
#                               title original_language  \
# 0                             Ariel                fi
# 1               Shadows in Paradise                fi
# 2                        Four Rooms                en
# 3                    Judgment Night                en
# 4  Life in Loops (A Megacities RMX)                en
# 5                  Sunday in August                de
# 6                         Star Wars                en
# 7                      Finding Nemo                en
# 8                      Forrest Gump                en
# 9                   American Beauty                en
#
#                      original_title  \
# 0                             Ariel
# 1              Varjoja paratiisissa
# 2                        Four Rooms
# 3                    Judgment Night
# 4  Life in Loops (A Megacities RMX)
# 5                 Sonntag im August
# 6                         Star Wars
# 7                      Finding Nemo
# 8                      Forrest Gump
# 9                   American Beauty
#
#                                             overview  \
# 0  A Finnish man goes to the city to find a job a...
# 1  Nikander, a rubbish collector and would-be ent...
# 2  It's Ted the Bellhop's first night on the job....
# 3  Four young friends, while taking a shortcut en...
# 4  Timo Novotny labels his new project an experim...
# 5                        This is a Drama type movie.
# 6  Princess Leia is captured and held hostage by ...
# 7  Nemo, an adventurous young clownfish, is unexp...
# 8  A man with a low IQ has accomplished great thi...
# 9  Lester Burnham, a depressed suburban father in...
#
#                                genres  \
# 0       Comedy, Drama, Romance, Crime
# 1              Comedy, Drama, Romance
# 2                              Comedy
# 3             Action, Crime, Thriller
# 4                         Documentary
# 5                               Drama
# 6  Adventure, Action, Science Fiction
# 7                   Animation, Family
# 8              Comedy, Drama, Romance
# 9                               Drama
#
#                                 production_companies  \
# 0                          Villealfa Filmproductions
# 1                          Villealfa Filmproductions
# 2                              Miramax, A Band Apart
# 3       Largo Entertainment, JVC, Universal Pictures
# 4                                            inLoops
# 5                                            Unknown
# 6                   Lucasfilm Ltd., 20th Century Fox
# 7                                              Pixar
# 8  Paramount Pictures, The Steve Tisch Company, W...
# 9           DreamWorks Pictures, Jinks/Cohen Company
#
#        production_countries  imdb_rating  \
# 0                   Finland          7.4
# 1                   Finland          7.4
# 2  United States of America          6.7
# 3  United States of America          6.6
# 4                   Austria          8.1
# 5                   Germany          6.8
# 6  United States of America          8.6
# 7  United States of America          8.2
# 8  United States of America          8.8
# 9  United States of America          8.3
#
#                                             director
# 0                                     Aki Kaurismäki
# 1                                     Aki Kaurismäki
# 2  Allison Anders, Robert Rodriguez, Alexandre Ro...
# 3                                    Stephen Hopkins
# 4                                       Timo Novotny
# 5                              Anna Haas, Marc Meyer
# 6                                       George Lucas
# 7                                     Andrew Stanton
# 8                                    Robert Zemeckis
# 9                                         Sam Mendes

# %%
# ml_model/train_model.py
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import MiniBatchKMeans
# from sklearn.metrics.pairwise import cosine_similarity
import joblib
import os
import time
from pathlib import Path

# %%
os.makedirs('ml_model2/artifacts', exist_ok=True)

# %%
df.isnull().sum()
# Out:
# title                   0
# original_language       0
# original_title          0
# overview                0
# genres                  0
# production_companies    0
# production_countries    0
# imdb_rating             0
# director                0
# dtype: int64

# %%
def train_and_save_models():
    """
    Main function to load data, train models, and save artifacts.
    Run this in Google Colab for better performance with 1M rows.
    """
    print("🚀 Starting model training process...")
    start_time = time.time()
    artifacts_dir = Path('/content/drive/MyDrive/ml project/movie_recommender_backend/ml_model2/artifacts')

    # Create artifacts directory if it doesn't exist
    artifacts_dir.mkdir(parents=True, exist_ok=True)
    print(f"📁 Artifacts will be saved to: {artifacts_dir}")

    # 2. Load your dataset from your specific path
    print("📦 Loading dataset...")
    try:
        df = pd.read_csv(file_path)
        print(f"✅ Dataset loaded successfully! Shape: {df.shape}")
        print(f"   Columns available: {list(df.columns)}")
    except FileNotFoundError:
        print(f"❌ Dataset file not found at: {file_path}")
        print("   Please check the file path in Google Drive")
        return False
    except Exception as e:
        print(f"❌ Error loading dataset: {e}")
        return False

    # 3. Handle missing values
    print("🔧 Preprocessing data...")
    # df['overview'] = df['overview'].fillna('')
    # df['genres'] = df['genres'].fillna('')
    # df['director'] = df['director'].fillna('')

    # 4. Combine text features
    print("🔄 Combining text features...")
    df['combined_text'] = df['overview'] + ' ' + df['genres']

    # Check if we have enough data
    if len(df) == 0:
        print("❌ No data available after preprocessing!")
        return False

    # 5. Train TF-IDF Vectorizer
    print("📊 Training TF-IDF Vectorizer...")
    try:
        tfidf = TfidfVectorizer(
            max_features=50000,      # Reduce dimensionality
            stop_words='english',    # Remove common words
            ngram_range=(1, 2),      # Use single words and two-word phrases
            min_df=2,                # Ignore terms that appear in less than 2 documents
            max_df=0.85              # Ignore terms that appear in more than 85% of documents
        )
        tfidf_matrix = tfidf.fit_transform(df['combined_text'])
        print(f"✅ TF-IDF training completed! Matrix shape: {tfidf_matrix.shape}")
    except Exception as e:
        print(f"❌ Error in TF-IDF training: {e}")
        return False

    # 6. Apply Dimensionality Reduction with SVD
    print("🎯 Applying SVD for dimensionality reduction...")
    try:
        svd = TruncatedSVD(
            n_components=300,    # Reduce to 300 dimensions
            random_state=42,     # For reproducible results
            n_iter=10            # Number of iterations
        )
        svd_matrix = svd.fit_transform(tfidf_matrix)
        print(f"✅ SVD completed! Explained variance ratio: {svd.explained_variance_ratio_.sum():.4f}")
        print(f"   Reduced matrix shape: {svd_matrix.shape}")
    except Exception as e:
        print(f"❌ Error in SVD: {e}")
        return False

    # 7. Cluster movies using MiniBatchKMeans
    print("📦 Clustering movies with MiniBatchKMeans...")
    try:
        kmeans = MiniBatchKMeans(
            n_clusters=500,        # Number of clusters
            random_state=42,       # For reproducible results
            batch_size=1000,       # Size of mini-batches
            n_init=3,              # Number of random initializations
            max_iter=100,          # Maximum number of iterations
            verbose=1              # Show progress
        )
        df['cluster'] = kmeans.fit_predict(svd_matrix)
        print("✅ Clustering completed!")
        print(f"   Number of clusters: {kmeans.n_clusters}")
    except Exception as e:
        print(f"❌ Error in clustering: {e}")
        return False

    # 8. Prepare final dataset for saving (keep only essential columns)
    print("💾 Preparing data for saving...")
    essential_columns = ['title', 'cluster', 'imdb_rating', 'overview', 'genres', 'director']

    # Ensure all essential columns exist
    for col in essential_columns:
        if col not in df.columns:
            print(f"❌ Column '{col}' not found in dataset!")
            return False

    movies_preprocessed = df[essential_columns].copy()

    # 9. Save ALL artifacts using joblib to your specific Google Drive path
    print("💾 Saving models and processed data...")
    try:
        # Save the trained models
        joblib.dump(tfidf, artifacts_dir / 'tfidf_vectorizer.pkl', compress=3)
        joblib.dump(svd, artifacts_dir / 'svd_model.pkl', compress=3)
        joblib.dump(kmeans, artifacts_dir / 'kmeans_model.pkl', compress=3)

        # Save the preprocessed movie data
        joblib.dump(movies_preprocessed, artifacts_dir / 'movies_preprocessed.pkl', compress=3)

        # Create a flag file to indicate training is complete
        with open(artifacts_dir / 'models_trained.flag', 'w') as f:
            f.write('Training completed successfully')

        print("✅ All models and data saved successfully!")
        print(f"📁 Files saved to: {artifacts_dir}")
        print("   - tfidf_vectorizer.pkl")
        print("   - svd_model.pkl")
        print("   - kmeans_model.pkl")
        print("   - movies_preprocessed.pkl")
        print("   - models_trained.flag")

        # Show some statistics
        print(f"\n📊 Dataset Statistics:")
        print(f"   Total movies processed: {len(movies_preprocessed)}")
        print(f"   Number of clusters: {kmeans.n_clusters}")
        print(f"   Unique clusters used: {movies_preprocessed['cluster'].nunique()}")
        print(f"   Average movies per cluster: {len(movies_preprocessed) / movies_preprocessed['cluster'].nunique():.1f}")

        end_time = time.time()
        print(f"\n⏰ Total execution time: {(end_time - start_time) / 60:.2f} minutes")

    except Exception as e:
        print(f"❌ Error saving files: {e}")
        return False

    return True

# %%
def check_artifacts():
    """Check if all required artifact files exist in your Google Drive path"""
    artifacts_dir = Path('/content/drive/MyDrive/ml project/movie_recommender_backend/ml_model2/artifacts')
    required_files = [
        'tfidf_vectorizer.pkl',
        'svd_model.pkl',
        'kmeans_model.pkl',
        'movies_preprocessed.pkl',
        'models_trained.flag'
    ]

    print("🔍 Checking for required artifact files...")
    print(f"📁 Checking path: {artifacts_dir}")
    missing_files = []

    for file in required_files:
        file_path = artifacts_dir / file
        if file_path.exists():
            print(f"   ✅ {file}")
        else:
            print(f"   ❌ {file} (missing)")
            missing_files.append(file)

    if missing_files:
        print(f"\n❌ Missing {len(missing_files)} files. Please run training first.")
        return False
    else:
        print(f"\n✅ All required files are present!")
        return True

if __name__ == "__main__":
    # First, mount Google Drive in Colab
    print("📂 Mounting Google Drive...")
    from google.colab import drive
    drive.mount('/content/drive')
    print("✅ Google Drive mounted successfully!")

    # Check if artifacts already exist
    if check_artifacts():
        print("Models are already trained. Would you like to retrain? (y/n)")
        response = input().lower()
        if response != 'y':
            print("Exiting without retraining.")
            exit()

    # Run the training process
    success = train_and_save_models()

    if success:
        print("\n🎉 Training completed successfully! You can now:")
        print("   1. Download the .pkl files from Google Drive")
        print("   2. Place them in your local movie_recommender_backend/ml_model/artifacts/ folder")
        print("   3. Use test_recommendations.py to test the system")
        print("   4. Run app.py to start the web server")
    else:
        print("\n💥 Training failed! Please check the error messages above.")
# Out:
# 📂 Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Google Drive mounted successfully!
# 🔍 Checking for required artifact files...
# 📁 Checking path: /content/drive/MyDrive/ml project/movie_recommender_backend/ml_model2/artifacts
#    ❌ tfidf_vectorizer.pkl (missing)
#    ❌ svd_model.pkl (missing)
#    ❌ kmeans_model.pkl (missing)
#    ❌ movies_preprocessed.pkl (missing)
#    ❌ models_trained.flag (missing)
#
# ❌ Missing 5 files. Please run training first.
# 🚀 Starting model training process...
# 📁 Artifacts will be saved to: /content/drive/MyDrive/ml project/movie_recommender_backend/ml_model2/artifacts
# 📦 Loading dataset...
# ✅ Dataset loaded successfully! Shape: (1039268, 9)
#    Columns available: ['title', 'original_language', 'original_title', 'overview', 'genres', 'production_companies', 'production_countries', 'imdb_rating', 'director']
# 🔧 Preprocessing data...
# 🔄 Combining text features...
# 📊 Training TF-IDF Vectorizer...
# ✅ TF-IDF training completed! Matrix shape: (1039268, 50000)
# 🎯 Applying SVD for dimensionality reduction...
# ✅ SVD completed! Explained variance ratio: 0.2188
#    Reduced matrix shape: (1039268, 300)
# 📦 Clustering movies with MiniBatchKMeans...
# Init 1/3 with method k-means++
# Inertia for init 1/3: 313.6974948428007
# Init 2/3 with method k-means++
# Inertia for init 2/3: 320.62905632756207
# Init 3/3 with method k-means++
# Inertia for init 3/3: 316.43459934687905
# [MiniBatchKMeans] Reassigning 412 cluster centers.
# Minibatch step 1/103926: mean batch inertia: 0.10792161095305758
# Minibatch step 2/103926: mean batch inertia: 0.11500362582728738, ewa inertia: 0.11500362582728738
# Minibatch step 3/103926: mean batch inertia: 0.11544524090747263, ewa inertia: 0.11500447568440847
# Minibatch step 4/103926: mean batch inertia: 0.1042216238279062, ewa inertia: 0.11498372484539277
# Minibatch step 5/103926: mean batch inertia: 0.09908111801219587, ewa inertia: 0.11495312139848307
# [MiniBatchKMeans] Reassigning 288 cluster centers.
# Minibatch step 6/103926: mean batch inertia: 0.09887136120623846, ewa inertia: 0.11492217318355076
# Minibatch step 7/103926: mean batch inertia: 0.09627806784708393, ewa inertia: 0.1148862939158415
# Minibatch step 8/103926: mean batch inertia: 0.09889059254225892, ewa inertia: 0.11485551131504501
# Minibatch step 9/103926: mean batch inertia: 0.09338471825283791, ewa inertia: 0.114814192285877
# Minibatch step 10/103926: mean batch inertia: 0.09189927462121301, ewa inertia: 0.11477009414061401
# [MiniBatchKMeans] Reassigning 211 cluster centers.
# Minibatch step 11/103926: mean batch inertia: 0.09352199456772285, ewa inertia: 0.114729203669383
# Minibatch step 12/103926: mean batch inertia: 0.08893853724393692, ewa inertia: 0.11467957134815443
# Minibatch step 13/103926: mean batch inertia: 0.09183503068904522, ewa inertia: 0.11463560863848232
# Minibatch step 14/103926: mean batch inertia: 0.09221582248367714, ewa inertia: 0.11459246333894042
# Minibatch step 15/103926: mean batch inertia: 0.09232708307656824, ewa inertia: 0.11454961518266449
# [MiniBatchKMeans] Reassigning 142 cluster centers.
# Minibatch step 16/103926: mean batch inertia: 0.08905925722207327, ewa inertia: 0.11450056078392731
# Minibatch step 17/103926: mean batch inertia: 0.09391313661144604, ewa inertia: 0.11446094173597635
# Minibatch step 18/103926: mean batch inertia: 0.09060027006496622, ewa inertia: 0.11441502355373286
# Minibatch step 19/103926: mean batch inertia: 0.08553451999593725, ewa inertia: 0.11435944505854481
# Minibatch step 20/103926: mean batch inertia: 0.08959227095406846, ewa inertia: 0.11431178237620852
# [MiniBatchKMeans] Reassigning 122 cluster centers.
# Minibatch step 21/103926: mean batch inertia: 0.08866279515994507, ewa inertia: 0.11426242270664028
# Minibatch step 22/103926: mean batch inertia: 0.08611785681092027, ewa inertia: 0.1142082604716545
# Minibatch step 23/103926: mean batch inertia: 0.08475960806783125, ewa inertia: 0.11415158861402414
# Minibatch step 24/103926: mean batch inertia: 0.08934250381795754, ewa inertia: 0.11410384527751344
# Minibatch step 25/103926: mean batch inertia: 0.08850833654187441, ewa inertia: 0.11405458852351492
# [MiniBatchKMeans] Reassigning 96 cluster centers.
# Minibatch step 26/103926: mean batch inertia: 0.08873674738546988, ewa inertia: 0.11400586612125325
# Minibatch step 27/103926: mean batch inertia: 0.08758195147564925, ewa inertia: 0.11395501515842149
# Minibatch step 28/103926: mean batch inertia: 0.08957468208663831, ewa inertia: 0.11390809692440934
# Minibatch step 29/103926: mean batch inertia: 0.08945896253881229, ewa inertia: 0.11386104628711409
# Minibatch step 30/103926: mean batch inertia: 0.08447505860447918, ewa inertia: 0.1138044950233265
# [MiniBatchKMeans] Reassigning 78 cluster centers.
# Minibatch step 31/103926: mean batch inertia: 0.085422727838283, ewa inertia: 0.11374987631116432
# Minibatch step 32/103926: mean batch inertia: 0.08706735828561407, ewa inertia: 0.11369852768433998
# Minibatch step 33/103926: mean batch inertia: 0.08658058319857069, ewa inertia: 0.11364634110995786
# Minibatch step 34/103926: mean batch inertia: 0.08910203210180147, ewa inertia: 0.11359910731580418
# Minibatch step 35/103926: mean batch inertia: 0.08731125679393703, ewa inertia: 0.11354851819879623
# [MiniBatchKMeans] Reassigning 65 cluster centers.
# Minibatch step 36/103926: mean batch inertia: 0.08368118911299827, ewa inertia: 0.11349104062737671
# Minibatch step 37/103926: mean batch inertia: 0.08812199894244019, ewa inertia: 0.11344221969326833
# Minibatch step 38/103926: mean batch inertia: 0.08799976132720291, ewa inertia: 0.11339325747392749
# Minibatch step 39/103926: mean batch inertia: 0.0867079534696033, ewa inertia: 0.11334190348568321
# Minibatch step 40/103926: mean batch inertia: 0.08376798505087815, ewa inertia: 0.11328499056239809
# Minibatch step 41/103926: mean batch inertia: 0.08181336502735441, ewa inertia: 0.11322442563544453
# Minibatch step 42/103926: mean batch inertia: 0.0849987530890966, ewa inertia: 0.11317010731642155
# Minibatch step 43/103926: mean batch inertia: 0.08616296313990632, ewa inertia: 0.11311813396943146
# Minibatch step 44/103926: mean batch inertia: 0.08399087603856734, ewa inertia: 0.1130620806128301
# Minibatch step 45/103926: mean batch inertia: 0.08322414396358177, ewa inertia: 0.11300465960508477
# [MiniBatchKMeans] Reassigning 46 cluster centers.
# Minibatch step 46/103926: mean batch inertia: 0.0839404522986142, ewa inertia: 0.11294872758496972
# Minibatch step 47/103926: mean batch inertia: 0.08467792636175106, ewa inertia: 0.11289432241898628
# Minibatch step 48/103926: mean batch inertia: 0.08374748483297281, ewa inertia: 0.1128382313827175
# Minibatch step 49/103926: mean batch inertia: 0.08373270707040492, ewa inertia: 0.11278221985093446
# Minibatch step 50/103926: mean batch inertia: 0.0830408243685255, ewa inertia: 0.11272498462986578
# [MiniBatchKMeans] Reassigning 40 cluster centers.
# Minibatch step 51/103926: mean batch inertia: 0.08311595288260974, ewa inertia: 0.1126680041334837
# Minibatch step 52/103926: mean batch inertia: 0.0816219007787771, ewa inertia: 0.11260825809399883
# Minibatch step 53/103926: mean batch inertia: 0.08246281396297073, ewa inertia: 0.112550245309761
# Minibatch step 54/103926: mean batch inertia: 0.07841323387190016, ewa inertia: 0.11248455103534723
# Minibatch step 55/103926: mean batch inertia: 0.08432470261600881, ewa inertia: 0.11243035939022102
# Minibatch step 56/103926: mean batch inertia: 0.08396874756518853, ewa inertia: 0.11237558702267222
# Minibatch step 57/103926: mean batch inertia: 0.0830197009347799, ewa inertia: 0.11231909368728381
# Minibatch step 58/103926: mean batch inertia: 0.08302162114933119, ewa inertia: 0.11226271276465848
# Minibatch step 59/103926: mean batch inertia: 0.08138682921253353, ewa inertia: 0.11220329430119594
# Minibatch step 60/103926: mean batch inertia: 0.08084539526641668, ewa inertia: 0.11214294823288296
# [MiniBatchKMeans] Reassigning 35 cluster centers.
# Minibatch step 61/103926: mean batch inertia: 0.0833821633727935, ewa inertia: 0.11208760012789745
# Minibatch step 62/103926: mean batch inertia: 0.08425715073580041, ewa inertia: 0.11203404238800124
# Minibatch step 63/103926: mean batch inertia: 0.08667766524089623, ewa inertia: 0.11198524582590402
# Minibatch step 64/103926: mean batch inertia: 0.08549844992155313, ewa inertia: 0.11193427385251821
# Minibatch step 65/103926: mean batch inertia: 0.08410072870646543, ewa inertia: 0.11188071015506153
# [MiniBatchKMeans] Reassigning 37 cluster centers.
# Minibatch step 66/103926: mean batch inertia: 0.0838669073348978, ewa inertia: 0.11182679956440567
# Minibatch step 67/103926: mean batch inertia: 0.07977908729419633, ewa inertia: 0.1117651259991012
# Minibatch step 68/103926: mean batch inertia: 0.08408602672814985, ewa inertia: 0.1117118595218543
# Minibatch step 69/103926: mean batch inertia: 0.08194488007462725, ewa inertia: 0.1116545750662471
# Minibatch step 70/103926: mean batch inertia: 0.08096612293838983, ewa inertia: 0.1115955173013607
# Minibatch step 71/103926: mean batch inertia: 0.08466627971304694, ewa inertia: 0.11154369388011305
# Minibatch step 72/103926: mean batch inertia: 0.08548196819905673, ewa inertia: 0.1114935399244364
# Minibatch step 73/103926: mean batch inertia: 0.07937827312291498, ewa inertia: 0.11143173635519395
# Minibatch step 74/103926: mean batch inertia: 0.08275282346256904, ewa inertia: 0.111376545807044
# Minibatch step 75/103926: mean batch inertia: 0.08255532719827964, ewa inertia: 0.1113210814015652
# [MiniBatchKMeans] Reassigning 24 cluster centers.
# Minibatch step 76/103926: mean batch inertia: 0.08134278197886027, ewa inertia: 0.11126339027554738
# Minibatch step 77/103926: mean batch inertia: 0.08468220095503766, ewa inertia: 0.11121223664867982
# Minibatch step 78/103926: mean batch inertia: 0.07992689070359588, ewa inertia: 0.11115203020367842
# Minibatch step 79/103926: mean batch inertia: 0.08079407710507347, ewa inertia: 0.11109360846089844
# Minibatch step 80/103926: mean batch inertia: 0.08118006910962101, ewa inertia: 0.11103604196107736
# Minibatch step 81/103926: mean batch inertia: 0.08416437141684034, ewa inertia: 0.11098432932355189
# Minibatch step 82/103926: mean batch inertia: 0.08417231444330533, ewa inertia: 0.11093273148915049
# Minibatch step 83/103926: mean batch inertia: 0.08179433874408278, ewa inertia: 0.11087665670438338
# Minibatch step 84/103926: mean batch inertia: 0.08119427086378173, ewa inertia: 0.11081953504321461
# Minibatch step 85/103926: mean batch inertia: 0.08300902033182832, ewa inertia: 0.11076601566620753
# [MiniBatchKMeans] Reassigning 21 cluster centers.
# Minibatch step 86/103926: mean batch inertia: 0.08415720666401191, ewa inertia: 0.11071480888720768
# Minibatch step 87/103926: mean batch inertia: 0.0823003082375705, ewa inertia: 0.11066012718179813
# Minibatch step 88/103926: mean batch inertia: 0.08175080604727201, ewa inertia: 0.11060449322921313
# Minibatch step 89/103926: mean batch inertia: 0.08354180201041232, ewa inertia: 0.11055241298585208
# Minibatch step 90/103926: mean batch inertia: 0.0826032148684953, ewa inertia: 0.11049862672239699
# Minibatch step 91/103926: mean batch inertia: 0.08326831182549316, ewa inertia: 0.11044622389907233
# Minibatch step 92/103926: mean batch inertia: 0.08333855530008848, ewa inertia: 0.11039405709991064
# Minibatch step 93/103926: mean batch inertia: 0.0794316044709443, ewa inertia: 0.11033447204035635
# Minibatch step 94/103926: mean batch inertia: 0.08414171147466348, ewa inertia: 0.11028406591727234
# Minibatch step 95/103926: mean batch inertia: 0.08428630949418442, ewa inertia: 0.11023403506592762
# [MiniBatchKMeans] Reassigning 15 cluster centers.
# Minibatch step 96/103926: mean batch inertia: 0.0842136939050856, ewa inertia: 0.11018396075184561
# Minibatch step 97/103926: mean batch inertia: 0.08064578008875405, ewa inertia: 0.11012711660338531
# Minibatch step 98/103926: mean batch inertia: 0.08143145846119172, ewa inertia: 0.11007189383018186
# Minibatch step 99/103926: mean batch inertia: 0.08482444705032213, ewa inertia: 0.110023306896905
# Minibatch step 100/103926: mean batch inertia: 0.07985693797638864, ewa inertia: 0.10996525384438344
# Minibatch step 101/103926: mean batch inertia: 0.08023626593273211, ewa inertia: 0.10990804250081089
# Minibatch step 102/103926: mean batch inertia: 0.08007741340873516, ewa inertia: 0.10985063555594468
# Minibatch step 103/103926: mean batch inertia: 0.08311463312145831, ewa inertia: 0.10979918400214199
# Minibatch step 104/103926: mean batch inertia: 0.07874928981100682, ewa inertia: 0.10973943066745938
# Minibatch step 105/103926: mean batch inertia: 0.07863262717110323, ewa inertia: 0.1096795678148267
# Minibatch step 106/103926: mean batch inertia: 0.08100742983631314, ewa inertia: 0.10962439030452183
# Minibatch step 107/103926: mean batch inertia: 0.08089262461111617, ewa inertia: 0.10956909804487894
# Minibatch step 108/103926: mean batch inertia: 0.08237117639024494, ewa inertia: 0.10951675756006772
# Minibatch step 109/103926: mean batch inertia: 0.08314976521115948, ewa inertia: 0.1094660161401872
# Minibatch step 110/103926: mean batch inertia: 0.07845221146290922, ewa inertia: 0.10940633225723238
# [MiniBatchKMeans] Reassigning 13 cluster centers.
# Minibatch step 111/103926: mean batch inertia: 0.08375582741663265, ewa inertia: 0.10935696966710297
# Minibatch step 112/103926: mean batch inertia: 0.08170007142814889, ewa inertia: 0.10930374591417866
# Minibatch step 113/103926: mean batch inertia: 0.08380458107948066, ewa inertia: 0.1092546745672325
# Minibatch step 114/103926: mean batch inertia: 0.08080334062684172, ewa inertia: 0.10919992197874888
# Minibatch step 115/103926: mean batch inertia: 0.08040669504932248, ewa inertia: 0.10914451144128567
# Minibatch step 116/103926: mean batch inertia: 0.08050911418710267, ewa inertia: 0.10908940463591732
# Minibatch step 117/103926: mean batch inertia: 0.08009305102681574, ewa inertia: 0.10903360319546426
# Minibatch step 118/103926: mean batch inertia: 0.07918737881551671, ewa inertia: 0.10897616623856486
# Minibatch step 119/103926: mean batch inertia: 0.08160837543377371, ewa inertia: 0.1089234988525372
# Minibatch step 120/103926: mean batch inertia: 0.08197955025946456, ewa inertia: 0.10887164712099691
# [MiniBatchKMeans] Reassigning 11 cluster centers.
# Minibatch step 121/103926: mean batch inertia: 0.08187884053744349, ewa inertia: 0.10881970136569476
# Minibatch step 122/103926: mean batch inertia: 0.08139234567608342, ewa inertia: 0.10876691935124111
# Minibatch step 123/103926: mean batch inertia: 0.0773397868619662, ewa inertia: 0.10870644004802071
# Minibatch step 124/103926: mean batch inertia: 0.08433621466731832, ewa inertia: 0.10865954126554822
# Minibatch step 125/103926: mean batch inertia: 0.08301675125447998, ewa inertia: 0.10861019352206493
# Minibatch step 126/103926: mean batch inertia: 0.08116388532255837, ewa inertia: 0.10855737503484073
# Minibatch step 127/103926: mean batch inertia: 0.08352895495619057, ewa inertia: 0.10850920960302539
# Minibatch step 128/103926: mean batch inertia: 0.07969513212417254, ewa inertia: 0.1084537589401482
# Minibatch step 129/103926: mean batch inertia: 0.08011590597216421, ewa inertia: 0.10839922473780408
# Minibatch step 130/103926: mean batch inertia: 0.08063086767458093, ewa inertia: 0.10834578649022195
# [MiniBatchKMeans] Reassigning 8 cluster centers.
# Minibatch step 131/103926: mean batch inertia: 0.08188617928615448, ewa inertia: 0.10829486683957507
# Minibatch step 132/103926: mean batch inertia: 0.07694420410890068, ewa inertia: 0.10823453469701971
# Minibatch step 133/103926: mean batch inertia: 0.08067682190049735, ewa inertia: 0.10818150181949422
# Minibatch step 134/103926: mean batch inertia: 0.08063779762144171, ewa inertia: 0.10812849590052992
# Minibatch step 135/103926: mean batch inertia: 0.08316786179810712, ewa inertia: 0.10808046091805201
# Minibatch step 136/103926: mean batch inertia: 0.08296345908983575, ewa inertia: 0.108032125016898
# Minibatch step 137/103926: mean batch inertia: 0.07875679867652688, ewa inertia: 0.10797578671307026
# Minibatch step 138/103926: mean batch inertia: 0.07780465375579554, ewa inertia: 0.10791772449249547
# Minibatch step 139/103926: mean batch inertia: 0.08018758360092602, ewa inertia: 0.10786435978924429
# Minibatch step 140/103926: mean batch inertia: 0.0783751611126046, ewa inertia: 0.10780760990316736
# [MiniBatchKMeans] Reassigning 4 cluster centers.
# Minibatch step 141/103926: mean batch inertia: 0.08101575958628479, ewa inertia: 0.10775605087404808
# Minibatch step 142/103926: mean batch inertia: 0.07884722216576064, ewa inertia: 0.1077004178691027
# Minibatch step 143/103926: mean batch inertia: 0.08127696301620782, ewa inertia: 0.10764956779110962
# Minibatch step 144/103926: mean batch inertia: 0.07875175719525528, ewa inertia: 0.10759395598974568
# Minibatch step 145/103926: mean batch inertia: 0.07618455048471097, ewa inertia: 0.10753351080085803
# Minibatch step 146/103926: mean batch inertia: 0.07946485242037882, ewa inertia: 0.10747949464453954
# Minibatch step 147/103926: mean batch inertia: 0.08119812854304766, ewa inertia: 0.10742891800634194
# Minibatch step 148/103926: mean batch inertia: 0.08041217452720183, ewa inertia: 0.10737692618617
# Minibatch step 149/103926: mean batch inertia: 0.08071821614728593, ewa inertia: 0.10732562337613931
# Minibatch step 150/103926: mean batch inertia: 0.08294966775297791, ewa inertia: 0.10727871356621876
# [MiniBatchKMeans] Reassigning 7 cluster centers.
# Minibatch step 151/103926: mean batch inertia: 0.07831918044580226, ewa inertia: 0.1072229829842031
# Minibatch step 152/103926: mean batch inertia: 0.08275316360265575, ewa inertia: 0.1071758925400899
# Minibatch step 153/103926: mean batch inertia: 0.08003948085160167, ewa inertia: 0.10712367042687669
# Minibatch step 154/103926: mean batch inertia: 0.0802368954319105, ewa inertia: 0.10707192872189951
# Minibatch step 155/103926: mean batch inertia: 0.07777527790652036, ewa inertia: 0.1070155493806214
# Minibatch step 156/103926: mean batch inertia: 0.07876097456274318, ewa inertia: 0.1069611754412123
# Minibatch step 157/103926: mean batch inertia: 0.07891685586301934, ewa inertia: 0.10690720612320474
# Minibatch step 158/103926: mean batch inertia: 0.07987461226216834, ewa inertia: 0.1068551838000891
# Minibatch step 159/103926: mean batch inertia: 0.08331184274982432, ewa inertia: 0.10680987629827722
# Minibatch step 160/103926: mean batch inertia: 0.07778653634487424, ewa inertia: 0.10675402292450507
# Minibatch step 161/103926: mean batch inertia: 0.07736891185582483, ewa inertia: 0.1066974733476993
# Minibatch step 162/103926: mean batch inertia: 0.08298350253052111, ewa inertia: 0.1066518374809176
# Minibatch step 163/103926: mean batch inertia: 0.08055402315153186, ewa inertia: 0.10660161407517879
# Minibatch step 164/103926: mean batch inertia: 0.07727056388772507, ewa inertia: 0.10654516853473171
# Minibatch step 165/103926: mean batch inertia: 0.08290382832387581, ewa inertia: 0.10649967244043687
# [MiniBatchKMeans] Reassigning 7 cluster centers.
# Minibatch step 166/103926: mean batch inertia: 0.07864740458388994, ewa inertia: 0.10644607271244239
# Minibatch step 167/103926: mean batch inertia: 0.0828693654642506, ewa inertia: 0.10640070099973241
# Minibatch step 168/103926: mean batch inertia: 0.08471217340506419, ewa inertia: 0.10635896295579061
# Minibatch step 169/103926: mean batch inertia: 0.08161210513893252, ewa inertia: 0.10631133937071907
# Minibatch step 170/103926: mean batch inertia: 0.08294123821447805, ewa inertia: 0.10626636525688282
# Minibatch step 171/103926: mean batch inertia: 0.07935588014163353, ewa inertia: 0.10621457792344893
# Minibatch step 172/103926: mean batch inertia: 0.08159612913469096, ewa inertia: 0.10616720145250877
# Minibatch step 173/103926: mean batch inertia: 0.0811090835710389, ewa inertia: 0.10611897886936336
# Minibatch step 174/103926: mean batch inertia: 0.08088245711092085, ewa inertia: 0.10607041296052082
# Minibatch step 175/103926: mean batch inertia: 0.08112641449090231, ewa inertia: 0.10602240999214667
# [MiniBatchKMeans] Reassigning 4 cluster centers.
# Minibatch step 176/103926: mean batch inertia: 0.0812189004964722, ewa inertia: 0.10597467738490894
# Minibatch step 177/103926: mean batch inertia: 0.0796899742795416, ewa inertia: 0.1059240943248824
# Minibatch step 178/103926: mean batch inertia: 0.08059549323629926, ewa inertia: 0.10587535121585367
# Minibatch step 179/103926: mean batch inertia: 0.08202995744631797, ewa inertia: 0.10582946243485561
# Minibatch step 180/103926: mean batch inertia: 0.08068483152881636, ewa inertia: 0.1057810733634871
# Minibatch step 181/103926: mean batch inertia: 0.07808516480373284, ewa inertia: 0.1057277745379477
# Minibatch step 182/103926: mean batch inertia: 0.08182706007058234, ewa inertia: 0.10568177929616263
# Minibatch step 183/103926: mean batch inertia: 0.07956147634915765, ewa inertia: 0.10563151261266296
# Minibatch step 184/103926: mean batch inertia: 0.08231431343800254, ewa inertia: 0.10558664030496465
# Minibatch step 185/103926: mean batch inertia: 0.07905467529124956, ewa inertia: 0.1055355814068089
# Minibatch step 186/103926: mean batch inertia: 0.07949183532278997, ewa inertia: 0.10548546205160055
# Minibatch step 187/103926: mean batch inertia: 0.07713664731817399, ewa inertia: 0.10543090675411082
# Minibatch step 188/103926: mean batch inertia: 0.08106190207501589, ewa inertia: 0.1053840103207926
# Minibatch step 189/103926: mean batch inertia: 0.07971392659694412, ewa inertia: 0.10533461005248122
# Minibatch step 190/103926: mean batch inertia: 0.08074961794600026, ewa inertia: 0.10528729796656991
# [MiniBatchKMeans] Reassigning 2 cluster centers.
# Minibatch step 191/103926: mean batch inertia: 0.08100408357534551, ewa inertia: 0.10524056663061893
# Minibatch step 192/103926: mean batch inertia: 0.08010625156296655, ewa inertia: 0.10519219741135491
# Minibatch step 193/103926: mean batch inertia: 0.07886718853908195, ewa inertia: 0.10514153678571848
# Minibatch step 194/103926: mean batch inertia: 0.07975031061554591, ewa inertia: 0.10509267315913062
# Minibatch step 195/103926: mean batch inertia: 0.07594214162018084, ewa inertia: 0.10503657501410955
# Minibatch step 196/103926: mean batch inertia: 0.08454285134613466, ewa inertia: 0.10499713628618064
# Minibatch step 197/103926: mean batch inertia: 0.08059395979441336, ewa inertia: 0.10495017409161549
# Minibatch step 198/103926: mean batch inertia: 0.08058651837266963, ewa inertia: 0.10490328795199438
# Minibatch step 199/103926: mean batch inertia: 0.08028309356340557, ewa inertia: 0.10485590812177027
# Minibatch step 200/103926: mean batch inertia: 0.0817010781096527, ewa inertia: 0.10481134828209042
# Minibatch step 201/103926: mean batch inertia: 0.08592438848881927, ewa inertia: 0.10477500165808205
# Minibatch step 202/103926: mean batch inertia: 0.0793489763628731, ewa inertia: 0.1047260710630288
# Minibatch step 203/103926: mean batch inertia: 0.08158671827650174, ewa inertia: 0.10468154100817961
# Minibatch step 204/103926: mean batch inertia: 0.08029336727273183, ewa inertia: 0.10463460768536242
# Minibatch step 205/103926: mean batch inertia: 0.08023041791250615, ewa inertia: 0.10458764354080917
# [MiniBatchKMeans] Reassigning 4 cluster centers.
# Minibatch step 206/103926: mean batch inertia: 0.07847006504227091, ewa inertia: 0.10453738210031871
# Minibatch step 207/103926: mean batch inertia: 0.08343606937248944, ewa inertia: 0.10449677411003355
# Minibatch step 208/103926: mean batch inertia: 0.08147051610860727, ewa inertia: 0.1044524616981336
# Minibatch step 209/103926: mean batch inertia: 0.0822988706086083, ewa inertia: 0.10440982867224806
# Minibatch step 210/103926: mean batch inertia: 0.07701472746316859, ewa inertia: 0.10435710872927069
# Minibatch step 211/103926: mean batch inertia: 0.0778116054720733, ewa inertia: 0.10430602377771879
# Minibatch step 212/103926: mean batch inertia: 0.0790648365053482, ewa inertia: 0.10425744889042325
# Minibatch step 213/103926: mean batch inertia: 0.08162607910391363, ewa inertia: 0.10421389641308292
# Minibatch step 214/103926: mean batch inertia: 0.07639805416246803, ewa inertia: 0.10416036678360178
# Minibatch step 215/103926: mean batch inertia: 0.07826435549080243, ewa inertia: 0.1041105317335949
# [MiniBatchKMeans] Reassigning 4 cluster centers.
# Minibatch step 216/103926: mean batch inertia: 0.07855319221389047, ewa inertia: 0.10406134843356439
# Minibatch step 217/103926: mean batch inertia: 0.08209889865572594, ewa inertia: 0.10401908324567206
# Minibatch step 218/103926: mean batch inertia: 0.0818386505549631, ewa inertia: 0.10397639856501537
# Minibatch step 219/103926: mean batch inertia: 0.07659889444557297, ewa inertia: 0.10392371248639772
# Minibatch step 220/103926: mean batch inertia: 0.08277831009329979, ewa inertia: 0.10388301964865677
# Minibatch step 221/103926: mean batch inertia: 0.07856840419100834, ewa inertia: 0.10383430345398985
# Minibatch step 222/103926: mean batch inertia: 0.08191772194451322, ewa inertia: 0.1037921265363497
# Minibatch step 223/103926: mean batch inertia: 0.08206233708160326, ewa inertia: 0.10375030908686406
# Minibatch step 224/103926: mean batch inertia: 0.08073115311747973, ewa inertia: 0.10370601034232461
# Minibatch step 225/103926: mean batch inertia: 0.08077512034590327, ewa inertia: 0.103661881459434
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 226/103926: mean batch inertia: 0.07912034153547313, ewa inertia: 0.10361465299418783
# Minibatch step 227/103926: mean batch inertia: 0.07791212532458687, ewa inertia: 0.10356519028978772
# Minibatch step 228/103926: mean batch inertia: 0.08613204325642757, ewa inertia: 0.10353164142605108
# Minibatch step 229/103926: mean batch inertia: 0.08054955430771366, ewa inertia: 0.10348741401790489
# Minibatch step 230/103926: mean batch inertia: 0.07822234131077932, ewa inertia: 0.10343879316477231
# Minibatch step 231/103926: mean batch inertia: 0.07820690022919428, ewa inertia: 0.10339023616377338
# Minibatch step 232/103926: mean batch inertia: 0.07857488795826681, ewa inertia: 0.10334248077377231
# Minibatch step 233/103926: mean batch inertia: 0.07893933444186739, ewa inertia: 0.10329551863724769
# Minibatch step 234/103926: mean batch inertia: 0.07973488334818267, ewa inertia: 0.10325017785389119
# Minibatch step 235/103926: mean batch inertia: 0.08032479798094289, ewa inertia: 0.10320605957484516
# [MiniBatchKMeans] Reassigning 5 cluster centers.
# Minibatch step 236/103926: mean batch inertia: 0.0817449479887623, ewa inertia: 0.10316475917699613
# Minibatch step 237/103926: mean batch inertia: 0.07841455192292798, ewa inertia: 0.10311712914616857
# Minibatch step 238/103926: mean batch inertia: 0.08022622222926648, ewa inertia: 0.10307307720789868
# Minibatch step 239/103926: mean batch inertia: 0.07832069124931916, ewa inertia: 0.10302544298430773
# Minibatch step 240/103926: mean batch inertia: 0.07903129692738917, ewa inertia: 0.10297926794000847
# Minibatch step 241/103926: mean batch inertia: 0.08078292285319544, ewa inertia: 0.10293655263706608
# Minibatch step 242/103926: mean batch inertia: 0.0812860149638522, ewa inertia: 0.10289488770205268
# Minibatch step 243/103926: mean batch inertia: 0.07721583277106094, ewa inertia: 0.10284547016928496
# Minibatch step 244/103926: mean batch inertia: 0.07831208743741049, ewa inertia: 0.1027982574019805
# Minibatch step 245/103926: mean batch inertia: 0.0806200080648842, ewa inertia: 0.10275557692303405
# [MiniBatchKMeans] Reassigning 7 cluster centers.
# Minibatch step 246/103926: mean batch inertia: 0.07906693248201345, ewa inertia: 0.10270998979507966
# Minibatch step 247/103926: mean batch inertia: 0.0756175287438656, ewa inertia: 0.10265785226177267
# Minibatch step 248/103926: mean batch inertia: 0.08047545855291952, ewa inertia: 0.10261516380727465
# Minibatch step 249/103926: mean batch inertia: 0.07954143308734433, ewa inertia: 0.10257076003747119
# Minibatch step 250/103926: mean batch inertia: 0.07886774304237042, ewa inertia: 0.10252514525054865
# [MiniBatchKMeans] Reassigning 7 cluster centers.
# Minibatch step 251/103926: mean batch inertia: 0.07819386818811039, ewa inertia: 0.10247832142137171
# Minibatch step 252/103926: mean batch inertia: 0.0783529226199651, ewa inertia: 0.10243189379040916
# Minibatch step 253/103926: mean batch inertia: 0.07987823999505471, ewa inertia: 0.10238849087202065
# Minibatch step 254/103926: mean batch inertia: 0.0833318057501454, ewa inertia: 0.1023518176235703
# Minibatch step 255/103926: mean batch inertia: 0.08015793994341772, ewa inertia: 0.10230910706897828
# Minibatch step 256/103926: mean batch inertia: 0.08022026668174394, ewa inertia: 0.10226659865125921
# Minibatch step 257/103926: mean batch inertia: 0.07834542899723324, ewa inertia: 0.10222056404490797
# Minibatch step 258/103926: mean batch inertia: 0.07930412313907005, ewa inertia: 0.10217646296827461
# Minibatch step 259/103926: mean batch inertia: 0.08057195192609337, ewa inertia: 0.10213488660827122
# Minibatch step 260/103926: mean batch inertia: 0.0778935004986769, ewa inertia: 0.10208823576790248
# [MiniBatchKMeans] Reassigning 5 cluster centers.
# Minibatch step 261/103926: mean batch inertia: 0.08255040650892616, ewa inertia: 0.10205063659144484
# Minibatch step 262/103926: mean batch inertia: 0.07939526094996337, ewa inertia: 0.10200703791652722
# Minibatch step 263/103926: mean batch inertia: 0.08236919257997569, ewa inertia: 0.10196924626617193
# Minibatch step 264/103926: mean batch inertia: 0.07960992962665457, ewa inertia: 0.10192621733595364
# Minibatch step 265/103926: mean batch inertia: 0.08229158962567458, ewa inertia: 0.1018884318776935
# [MiniBatchKMeans] Reassigning 7 cluster centers.
# Minibatch step 266/103926: mean batch inertia: 0.08156954772347966, ewa inertia: 0.10184932961609576
# Minibatch step 267/103926: mean batch inertia: 0.08110058577030455, ewa inertia: 0.10180940011979443
# Minibatch step 268/103926: mean batch inertia: 0.08175589305120567, ewa inertia: 0.1017708085577088
# Minibatch step 269/103926: mean batch inertia: 0.0796422215049047, ewa inertia: 0.101728223650331
# Minibatch step 270/103926: mean batch inertia: 0.08104370276046036, ewa inertia: 0.10168841774658545
# Minibatch step 271/103926: mean batch inertia: 0.07945683132011463, ewa inertia: 0.10164563462416677
# Minibatch step 272/103926: mean batch inertia: 0.07925025665593913, ewa inertia: 0.10160253629646099
# Minibatch step 273/103926: mean batch inertia: 0.08013537973869528, ewa inertia: 0.10156122426548966
# Minibatch step 274/103926: mean batch inertia: 0.0810326228126823, ewa inertia: 0.10152171841772012
# Minibatch step 275/103926: mean batch inertia: 0.07949179739128465, ewa inertia: 0.10147932338616153
# [MiniBatchKMeans] Reassigning 6 cluster centers.
# Minibatch step 276/103926: mean batch inertia: 0.07975136841401614, ewa inertia: 0.10143750946700845
# Minibatch step 277/103926: mean batch inertia: 0.08246061621819716, ewa inertia: 0.10140098977239848
# Minibatch step 278/103926: mean batch inertia: 0.07890464010062251, ewa inertia: 0.10135769713176015
# Minibatch step 279/103926: mean batch inertia: 0.07809440160214051, ewa inertia: 0.10131292855783056
# Minibatch step 280/103926: mean batch inertia: 0.07951693582766502, ewa inertia: 0.10127098370480374
# [MiniBatchKMeans] Reassigning 8 cluster centers.
# Minibatch step 281/103926: mean batch inertia: 0.08230063104096312, ewa inertia: 0.10123447659708891
# Minibatch step 282/103926: mean batch inertia: 0.0788553734897488, ewa inertia: 0.10119140958920675
# Minibatch step 283/103926: mean batch inertia: 0.08048489956787852, ewa inertia: 0.1011515613689263
# Minibatch step 284/103926: mean batch inertia: 0.079445593723746, ewa inertia: 0.10110978976283552
# Minibatch step 285/103926: mean batch inertia: 0.07892285823196213, ewa inertia: 0.1010670925756186
# Minibatch step 286/103926: mean batch inertia: 0.07725649702886422, ewa inertia: 0.10102127076134962
# Minibatch step 287/103926: mean batch inertia: 0.07887190847513331, ewa inertia: 0.10097864587349822
# Minibatch step 288/103926: mean batch inertia: 0.08198957170737371, ewa inertia: 0.10094210273757072
# Minibatch step 289/103926: mean batch inertia: 0.07859996628413148, ewa inertia: 0.10089910686941062
# Minibatch step 290/103926: mean batch inertia: 0.07961117859416865, ewa inertia: 0.10085813975064686
# [MiniBatchKMeans] Reassigning 7 cluster centers.
# Minibatch step 291/103926: mean batch inertia: 0.08067072459868514, ewa inertia: 0.10081929049188525
# Minibatch step 292/103926: mean batch inertia: 0.08015529473681697, ewa inertia: 0.10077952408731614
# Minibatch step 293/103926: mean batch inertia: 0.0811938531037248, ewa inertia: 0.10074183284282873
# Minibatch step 294/103926: mean batch inertia: 0.08170105921763214, ewa inertia: 0.10070519021493317
# Minibatch step 295/103926: mean batch inertia: 0.07706632682081938, ewa inertia: 0.1006596988870977
# Minibatch step 296/103926: mean batch inertia: 0.07827641405355915, ewa inertia: 0.10061662383177798
# Minibatch step 297/103926: mean batch inertia: 0.08254138889032034, ewa inertia: 0.10058183931508123
# Minibatch step 298/103926: mean batch inertia: 0.08052227241231337, ewa inertia: 0.10054323609127147
# Minibatch step 299/103926: mean batch inertia: 0.08396167007499739, ewa inertia: 0.10051132603522964
# Minibatch step 300/103926: mean batch inertia: 0.08047606264339412, ewa inertia: 0.1004727695818151
# [MiniBatchKMeans] Reassigning 5 cluster centers.
# Minibatch step 301/103926: mean batch inertia: 0.08230069079850584, ewa inertia: 0.10043779869596493
# Minibatch step 302/103926: mean batch inertia: 0.0810652031646082, ewa inertia: 0.10040051750017952
# Minibatch step 303/103926: mean batch inertia: 0.07597925334302182, ewa inertia: 0.10035352049717614
# Minibatch step 304/103926: mean batch inertia: 0.07873303740971772, ewa inertia: 0.10031191340009644
# Minibatch step 305/103926: mean batch inertia: 0.08267463663894634, ewa inertia: 0.1002779717030745
# [MiniBatchKMeans] Reassigning 6 cluster centers.
# Minibatch step 306/103926: mean batch inertia: 0.08103377038171407, ewa inertia: 0.10024093759290406
# Minibatch step 307/103926: mean batch inertia: 0.08044916438417712, ewa inertia: 0.10020284971919913
# Minibatch step 308/103926: mean batch inertia: 0.07988264149504501, ewa inertia: 0.10016374490952204
# Minibatch step 309/103926: mean batch inertia: 0.08050915321232624, ewa inertia: 0.10012592103197504
# Minibatch step 310/103926: mean batch inertia: 0.07990655389968221, ewa inertia: 0.1000870102838775
# Minibatch step 311/103926: mean batch inertia: 0.08020274787213306, ewa inertia: 0.1000487444212149
# Minibatch step 312/103926: mean batch inertia: 0.07870247340394768, ewa inertia: 0.1000076650259529
# Minibatch step 313/103926: mean batch inertia: 0.07983606038808833, ewa inertia: 0.09996884619341222
# Minibatch step 314/103926: mean batch inertia: 0.08164058651588346, ewa inertia: 0.09993357474843015
# Minibatch step 315/103926: mean batch inertia: 0.079636340928523, ewa inertia: 0.09989451415137605
# [MiniBatchKMeans] Reassigning 6 cluster centers.
# Minibatch step 316/103926: mean batch inertia: 0.08076016717632378, ewa inertia: 0.09985769144815859
# Minibatch step 317/103926: mean batch inertia: 0.07931333523763212, ewa inertia: 0.09981815528146733
# Minibatch step 318/103926: mean batch inertia: 0.08091967457503688, ewa inertia: 0.09978178648627295
# Minibatch step 319/103926: mean batch inertia: 0.08234983360890288, ewa inertia: 0.09974823992060541
# Minibatch step 320/103926: mean batch inertia: 0.08036549687460752, ewa inertia: 0.09971093919664271
# [MiniBatchKMeans] Reassigning 6 cluster centers.
# Minibatch step 321/103926: mean batch inertia: 0.08072470325312955, ewa inertia: 0.09967440152267475
# Minibatch step 322/103926: mean batch inertia: 0.07898971660741255, ewa inertia: 0.09963459530327387
# Minibatch step 323/103926: mean batch inertia: 0.07909239451671735, ewa inertia: 0.09959506328454426
# Minibatch step 324/103926: mean batch inertia: 0.07781025625640214, ewa inertia: 0.09955313995761324
# Minibatch step 325/103926: mean batch inertia: 0.07887158547433806, ewa inertia: 0.09951333976250826
# [MiniBatchKMeans] Reassigning 4 cluster centers.
# Minibatch step 326/103926: mean batch inertia: 0.08053301948656177, ewa inertia: 0.0994768134728259
# Minibatch step 327/103926: mean batch inertia: 0.07884367790670066, ewa inertia: 0.09943710645651707
# Minibatch step 328/103926: mean batch inertia: 0.07844154126472276, ewa inertia: 0.09939670196991776
# Minibatch step 329/103926: mean batch inertia: 0.08255425717751078, ewa inertia: 0.09936428987104363
# Minibatch step 330/103926: mean batch inertia: 0.07995318311685862, ewa inertia: 0.09932693456312204
# Minibatch step 331/103926: mean batch inertia: 0.08138823824968719, ewa inertia: 0.09929241280539919
# Minibatch step 332/103926: mean batch inertia: 0.0809787340175224, ewa inertia: 0.09925716942031242
# Minibatch step 333/103926: mean batch inertia: 0.07846487413752425, ewa inertia: 0.0992171561123377
# Minibatch step 334/103926: mean batch inertia: 0.08145119270666547, ewa inertia: 0.09918296676693111
# Minibatch step 335/103926: mean batch inertia: 0.08090216653068734, ewa inertia: 0.09914778665430148
# [MiniBatchKMeans] Reassigning 4 cluster centers.
# Minibatch step 336/103926: mean batch inertia: 0.07886576102749324, ewa inertia: 0.09910875532434396
# Minibatch step 337/103926: mean batch inertia: 0.08038906460225224, ewa inertia: 0.09907273059788317
# Minibatch step 338/103926: mean batch inertia: 0.07777012862908943, ewa inertia: 0.09903173524062957
# Minibatch step 339/103926: mean batch inertia: 0.08173427638233226, ewa inertia: 0.09899844749922998
# Minibatch step 340/103926: mean batch inertia: 0.0777453715413753, ewa inertia: 0.09895754745129656
# [MiniBatchKMeans] Reassigning 5 cluster centers.
# Minibatch step 341/103926: mean batch inertia: 0.07823566416220337, ewa inertia: 0.09891766964624495
# Minibatch step 342/103926: mean batch inertia: 0.08000042816826314, ewa inertia: 0.09888126474726695
# Minibatch step 343/103926: mean batch inertia: 0.07945831748974162, ewa inertia: 0.09884388665313054
# Minibatch step 344/103926: mean batch inertia: 0.08258449263813292, ewa inertia: 0.0988125965944162
# Minibatch step 345/103926: mean batch inertia: 0.08123311563764474, ewa inertia: 0.09877876612134952
# Minibatch step 346/103926: mean batch inertia: 0.08253816108697427, ewa inertia: 0.09874751222070517
# Minibatch step 347/103926: mean batch inertia: 0.07938826578670738, ewa inertia: 0.0987102567143175
# Minibatch step 348/103926: mean batch inertia: 0.07952972710083145, ewa inertia: 0.0986733451358648
# Minibatch step 349/103926: mean batch inertia: 0.07819981207523384, ewa inertia: 0.0986339452633378
# Minibatch step 350/103926: mean batch inertia: 0.08129815000235414, ewa inertia: 0.09860058374623108
# Minibatch step 351/103926: mean batch inertia: 0.0832258637624189, ewa inertia: 0.0985709961803866
# Minibatch step 352/103926: mean batch inertia: 0.0802177162937068, ewa inertia: 0.09853567658577408
# Minibatch step 353/103926: mean batch inertia: 0.08140048259828107, ewa inertia: 0.09850270111169088
# Minibatch step 354/103926: mean batch inertia: 0.0798859746765638, ewa inertia: 0.09846687453274909
# Minibatch step 355/103926: mean batch inertia: 0.07956545045492572, ewa inertia: 0.09843050007324375
# Minibatch step 356/103926: mean batch inertia: 0.07832188193977833, ewa inertia: 0.09839180245379495
# Minibatch step 357/103926: mean batch inertia: 0.07726177032300495, ewa inertia: 0.09835113919504136
# Minibatch step 358/103926: mean batch inertia: 0.07978393509496967, ewa inertia: 0.09831540791834578
# Minibatch step 359/103926: mean batch inertia: 0.07675441368716807, ewa inertia: 0.0982739153033805
# Minibatch step 360/103926: mean batch inertia: 0.08195329187117523, ewa inertia: 0.09824250741296482
# [MiniBatchKMeans] Reassigning 2 cluster centers.
# Minibatch step 361/103926: mean batch inertia: 0.07856814392020105, ewa inertia: 0.09820464548598967
# Minibatch step 362/103926: mean batch inertia: 0.07824499506348458, ewa inertia: 0.09816623454440956
# Minibatch step 363/103926: mean batch inertia: 0.081764674822293, ewa inertia: 0.09813467089780388
# Minibatch step 364/103926: mean batch inertia: 0.0784068582505811, ewa inertia: 0.09809670611169514
# Minibatch step 365/103926: mean batch inertia: 0.07980647182487825, ewa inertia: 0.09806150784389958
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 366/103926: mean batch inertia: 0.08058170781931911, ewa inertia: 0.09802786919976687
# Minibatch step 367/103926: mean batch inertia: 0.07935870412804225, ewa inertia: 0.09799194170636194
# Minibatch step 368/103926: mean batch inertia: 0.07961455736949812, ewa inertia: 0.0979565757244326
# Minibatch step 369/103926: mean batch inertia: 0.08020293537543598, ewa inertia: 0.09792241009388075
# Minibatch step 370/103926: mean batch inertia: 0.0812006102149503, ewa inertia: 0.0978902301676462
# Minibatch step 371/103926: mean batch inertia: 0.07611558968302805, ewa inertia: 0.0978483264055122
# Minibatch step 372/103926: mean batch inertia: 0.08082961524524182, ewa inertia: 0.09781557509442668
# Minibatch step 373/103926: mean batch inertia: 0.08312628896205229, ewa inertia: 0.09778730659775761
# Minibatch step 374/103926: mean batch inertia: 0.0794292889528817, ewa inertia: 0.0977519778856631
# Minibatch step 375/103926: mean batch inertia: 0.08150648923284526, ewa inertia: 0.097720714586839
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Minibatch step 376/103926: mean batch inertia: 0.08105977746609619, ewa inertia: 0.0976886517866963
# Minibatch step 377/103926: mean batch inertia: 0.08025082387138817, ewa inertia: 0.097655093914932
# Minibatch step 378/103926: mean batch inertia: 0.07698316650575808, ewa inertia: 0.09761531224645315
# Minibatch step 379/103926: mean batch inertia: 0.07719088343197932, ewa inertia: 0.09757600687158971
# Minibatch step 380/103926: mean batch inertia: 0.07836200816563972, ewa inertia: 0.09753903088422561
# [MiniBatchKMeans] Reassigning 2 cluster centers.
# Minibatch step 381/103926: mean batch inertia: 0.07897461390166421, ewa inertia: 0.09750330497114139
# Minibatch step 382/103926: mean batch inertia: 0.08106840881476167, ewa inertia: 0.09747167717091569
# Minibatch step 383/103926: mean batch inertia: 0.07908045580310155, ewa inertia: 0.09743628456059475
# Minibatch step 384/103926: mean batch inertia: 0.08107120683370139, ewa inertia: 0.09740479112101964
# Minibatch step 385/103926: mean batch inertia: 0.0813019531055742, ewa inertia: 0.097373802343301
# Minibatch step 386/103926: mean batch inertia: 0.0804151897428765, ewa inertia: 0.09734116668766145
# Minibatch step 387/103926: mean batch inertia: 0.07818210723022005, ewa inertia: 0.09730429642701201
# Minibatch step 388/103926: mean batch inertia: 0.07828166903657394, ewa inertia: 0.0972676887202673
# Minibatch step 389/103926: mean batch inertia: 0.07960135864409587, ewa inertia: 0.09723369111218667
# Minibatch step 390/103926: mean batch inertia: 0.07858230514270834, ewa inertia: 0.09719779783341191
# [MiniBatchKMeans] Reassigning 3 cluster centers.
# Minibatch step 391/103926: mean batch inertia: 0.08081524921852341, ewa inertia: 0.09716627077234324
# Minibatch step 392/103926: mean batch inertia: 0.07794869773636239, ewa inertia: 0.09712928790643273
# Minibatch step 393/103926: mean batch inertia: 0.0819057654687029, ewa inertia: 0.0970999913096176
# Minibatch step 394/103926: mean batch inertia: 0.07546107048825806, ewa inertia: 0.09705834873041749
# Minibatch step 395/103926: mean batch inertia: 0.08635853853237269, ewa inertia: 0.09703775769922529
# Minibatch step 396/103926: mean batch inertia: 0.07926820309166205, ewa inertia: 0.09700356144280359
# Minibatch step 397/103926: mean batch inertia: 0.07895615196032833, ewa inertia: 0.09696883047424304
# Minibatch step 398/103926: mean batch inertia: 0.08118475664506729, ewa inertia: 0.0969384551357519
# Minibatch step 399/103926: mean batch inertia: 0.07933680487391125, ewa inertia: 0.09690458199941888
# Minibatch step 400/103926: mean batch inertia: 0.07963014579080865, ewa inertia: 0.09687133856348727
# Minibatch step 401/103926: mean batch inertia: 0.081557742459925, ewa inertia: 0.09684186862624569
# Minibatch step 402/103926: mean batch inertia: 0.07963669902076219, ewa inertia: 0.0968087584890137
# Minibatch step 403/103926: mean batch inertia: 0.07845376750382281, ewa inertia: 0.0967734356015126
# Minibatch step 404/103926: mean batch inertia: 0.07808881840843958, ewa inertia: 0.09673747837158835
# Minibatch step 405/103926: mean batch inertia: 0.07828851987131297, ewa inertia: 0.09670197465022214
# Minibatch step 406/103926: mean batch inertia: 0.08013868536662455, ewa inertia: 0.09667009976646519
# Minibatch step 407/103926: mean batch inertia: 0.0777145767326751, ewa inertia: 0.09663362119732902
# Minibatch step 408/103926: mean batch inertia: 0.07944244596011676, ewa inertia: 0.0966005379912732
# Minibatch step 409/103926: mean batch inertia: 0.08032277246202552, ewa inertia: 0.0965692125778735
# Minibatch step 410/103926: mean batch inertia: 0.07681279611716657, ewa inertia: 0.09653119274574014
# Minibatch step 411/103926: mean batch inertia: 0.08118205345454357, ewa inertia: 0.09650165440813709
# Minibatch step 412/103926: mean batch inertia: 0.08088681693327403, ewa inertia: 0.09647160475309136
# Minibatch step 413/103926: mean batch inertia: 0.0771888166708181, ewa inertia: 0.09643449638541701
# Minibatch step 414/103926: mean batch inertia: 0.08367753622622832, ewa inertia: 0.09640994651399934
# Minibatch step 415/103926: mean batch inertia: 0.07857515705598218, ewa inertia: 0.0963756247177021
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Minibatch step 416/103926: mean batch inertia: 0.07944754574683442, ewa inertia: 0.09634304782188231
# Minibatch step 417/103926: mean batch inertia: 0.08053736682811284, ewa inertia: 0.09631263090192459
# Minibatch step 418/103926: mean batch inertia: 0.0809037682949002, ewa inertia: 0.09628297763100623
# Minibatch step 419/103926: mean batch inertia: 0.07816280309972738, ewa inertia: 0.09624810663123373
# Minibatch step 420/103926: mean batch inertia: 0.07590551049685637, ewa inertia: 0.09620895873760008
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Minibatch step 421/103926: mean batch inertia: 0.07727601751140321, ewa inertia: 0.09617252362556229
# Minibatch step 422/103926: mean batch inertia: 0.08056283950068645, ewa inertia: 0.09614248388777569
# Minibatch step 423/103926: mean batch inertia: 0.08337727205252136, ewa inertia: 0.09611791813658856
# Minibatch step 424/103926: mean batch inertia: 0.0774822959094581, ewa inertia: 0.0960820551940258
# Minibatch step 425/103926: mean batch inertia: 0.08251631737085906, ewa inertia: 0.09605594888695194
# Minibatch step 426/103926: mean batch inertia: 0.07819329132876061, ewa inertia: 0.09602157346045853
# Minibatch step 427/103926: mean batch inertia: 0.08263456208792543, ewa inertia: 0.09599581109985211
# Minibatch step 428/103926: mean batch inertia: 0.07960346314741691, ewa inertia: 0.09596426518064845
# Minibatch step 429/103926: mean batch inertia: 0.0797585170161521, ewa inertia: 0.09593307835959539
# Minibatch step 430/103926: mean batch inertia: 0.08011091965545222, ewa inertia: 0.0959026297294445
# [MiniBatchKMeans] Reassigning 1 cluster centers.
# Minibatch step 431/103926: mean batch inertia: 0.0791806052484821, ewa inertia: 0.09587044937097915
# Minibatch step 432/103926: mean batch inertia: 0.08079856846319843, ewa inertia: 0.09584144459760906
# Minibatch step 433/103926: mean batch inertia: 0.07728442915303937, ewa inertia: 0.09580573292826344
# Minibatch step 434/103926: mean batch inertia: 0.07461570676892315, ewa inertia: 0.09576495421522699
# Minibatch step 435/103926: mean batch inertia: 0.07845756773635337, ewa inertia: 0.09573164736882077
# Minibatch step 436/103926: mean batch inertia: 0.08007255101334212, ewa inertia: 0.09570151254067623
# Minibatch step 437/103926: mean batch inertia: 0.08365999214147027, ewa inertia: 0.0956783394826918
# Minibatch step 438/103926: mean batch inertia: 0.07389460682541882, ewa inertia: 0.09563641822331186
# Minibatch step 439/103926: mean batch inertia: 0.08008433124257165, ewa inertia: 0.09560648932717285
# ...
# Minibatch step 1662/103926: mean batch inertia: 0.07844542359919798, ewa inertia: 0.08056235327182884
# Minibatch step 1663/103926: mean batch inertia: 0.0749942636158423, ewa inertia: 0.08055163787541851
# Minibatch step 1664/103926: mean batch inertia: 0.07794473780612016, ewa inertia: 0.08054662107982605
# Minibatch step 1665/103926: mean batch inertia: 0.07930025955214014, ewa inertia: 0.080544222544841
# Minibatch step 1666/103926: mean batch inertia: 0.08421462579550679, ewa inertia: 0.08055128597740883
# Minibatch step 1667/103926: mean batch inertia: 0.07602892294506075, ewa inertia: 0.08054258300824041
# Minibatch step 1668/103926: mean batch inertia: 0.07680001522579208, ewa inertia: 0.08053538070011336
# Minibatch step 1669/103926: mean batch inertia: 0.07989374574758966, ewa inertia: 0.08053414591883436
# Minibatch step 1670/103926: mean batch inertia: 0.07723168375472089, ewa inertia: 0.08052779056297536
# Minibatch step 1671/103926: mean batch inertia: 0.07704393087266474, ewa inertia: 0.08052108612035212
# Minibatch step 1672/103926: mean batch inertia: 0.08099334434159991, ewa inertia: 0.08052199494804013
# Minibatch step 1673/103926: mean batch inertia: 0.07773783515250252, ewa inertia: 0.08051663702858802
# Minibatch step 1674/103926: mean batch inertia: 0.07795097271119572, ewa inertia: 0.08051169958829607
# Minibatch step 1675/103926: mean batch inertia: 0.08203426837980243, ewa inertia: 0.08051462966470845
# Minibatch step 1676/103926: mean batch inertia: 0.07944307935399944, ewa inertia: 0.0805125675415994
# Minibatch step 1677/103926: mean batch inertia: 0.07582527289704707, ewa inertia: 0.0805035471731586
# Minibatch step 1678/103926: mean batch inertia: 0.08203398948619602, ewa inertia: 0.08050649240160866
# Minibatch step 1679/103926: mean batch inertia: 0.07882306969437593, ewa inertia: 0.08050325277316361
# Minibatch step 1680/103926: mean batch inertia: 0.07973698819495718, ewa inertia: 0.08050177815094703
# Minibatch step 1681/103926: mean batch inertia: 0.07814508840762105, ewa inertia: 0.08049724286750584
# Minibatch step 1682/103926: mean batch inertia: 0.07882486875655195, ewa inertia: 0.08049402450130623
# Minibatch step 1683/103926: mean batch inertia: 0.08233554910453082, ewa inertia: 0.0804975683857158
# Minibatch step 1684/103926: mean batch inertia: 0.07910226318884098, ewa inertia: 0.08049488321912876
# Minibatch step 1685/103926: mean batch inertia: 0.0793376330666308, ewa inertia: 0.08049265617270959
# Minibatch step 1686/103926: mean batch inertia: 0.07858866932632379, ewa inertia: 0.08048899208411196
# Minibatch step 1687/103926: mean batch inertia: 0.07726800323317856, ewa inertia: 0.08048279351790642
# Minibatch step 1688/103926: mean batch inertia: 0.0790452361577572, ewa inertia: 0.08048002704000676
# Minibatch step 1689/103926: mean batch inertia: 0.08240842176315473, ewa inertia: 0.0804837380998443
# Minibatch step 1690/103926: mean batch inertia: 0.07865347923568178, ewa inertia: 0.08048021589555616
# Minibatch step 1691/103926: mean batch inertia: 0.0793882153378449, ewa inertia: 0.08047811441738698
# Minibatch step 1692/103926: mean batch inertia: 0.08109182993521126, ewa inertia: 0.08047929546968012
# Minibatch step 1693/103926: mean batch inertia: 0.07803902463441903, ewa inertia: 0.08047459934031369
# Minibatch step 1694/103926: mean batch inertia: 0.07834920544303307, ewa inertia: 0.0804705091694392
# Minibatch step 1695/103926: mean batch inertia: 0.07961413302825819, ewa inertia: 0.08046886113386577
# Minibatch step 1696/103926: mean batch inertia: 0.08054647726407675, ewa inertia: 0.08046901050064224
# Minibatch step 1697/103926: mean batch inertia: 0.07734276628226829, ewa inertia: 0.08046299426380966
# Minibatch step 1698/103926: mean batch inertia: 0.08024079955529612, ewa inertia: 0.08046256666574118
# Minibatch step 1699/103926: mean batch inertia: 0.07754632510816889, ewa inertia: 0.08045695456423989
# Minibatch step 1700/103926: mean batch inertia: 0.08332375062492582, ewa inertia: 0.08046247151136462
# Minibatch step 1701/103926: mean batch inertia: 0.07756345248713646, ewa inertia: 0.08045689255341586
# Minibatch step 1702/103926: mean batch inertia: 0.07888633944502361, ewa inertia: 0.08045387013456493
# Minibatch step 1703/103926: mean batch inertia: 0.07726511569543584, ewa inertia: 0.0804477336012148
# Minibatch step 1704/103926: mean batch inertia: 0.08029558412070853, ewa inertia: 0.08044744080025468
# Minibatch step 1705/103926: mean batch inertia: 0.07754500649431616, ewa inertia: 0.08044185526983678
# Minibatch step 1706/103926: mean batch inertia: 0.07655337128405551, ewa inertia: 0.08043437215625256
# Minibatch step 1707/103926: mean batch inertia: 0.07961343307697925, ewa inertia: 0.08043279231680911
# Minibatch step 1708/103926: mean batch inertia: 0.0791780341163291, ewa inertia: 0.08043037762301862
# Minibatch step 1709/103926: mean batch inertia: 0.08087237466508629, ewa inertia: 0.08043122821519844
# Minibatch step 1710/103926: mean batch inertia: 0.07800222659844279, ewa inertia: 0.08042655377264939
# Minibatch step 1711/103926: mean batch inertia: 0.07560779789933626, ewa inertia: 0.08041728041633199
# Minibatch step 1712/103926: mean batch inertia: 0.08067491945958917, ewa inertia: 0.08041777622452652
# Minibatch step 1713/103926: mean batch inertia: 0.08223788934460201, ewa inertia: 0.08042127890404467
# Minibatch step 1714/103926: mean batch inertia: 0.07947686713440766, ewa inertia: 0.08041946145010419
# Minibatch step 1715/103926: mean batch inertia: 0.08097756856268756, ewa inertia: 0.08042053548793768
# Minibatch step 1716/103926: mean batch inertia: 0.07709771880452883, ewa inertia: 0.08041414096123976
# Minibatch step 1717/103926: mean batch inertia: 0.08045626157946931, ewa inertia: 0.08041422201940321
# Minibatch step 1718/103926: mean batch inertia: 0.07810339048258809, ewa inertia: 0.08040977498685087
# Minibatch step 1719/103926: mean batch inertia: 0.07804056655027768, ewa inertia: 0.08040521561206615
# Minibatch step 1720/103926: mean batch inertia: 0.07569316681983404, ewa inertia: 0.08039614760601145
# Minibatch step 1721/103926: mean batch inertia: 0.07828706738851723, ewa inertia: 0.08039208882966482
# Minibatch step 1722/103926: mean batch inertia: 0.07687081465700664, ewa inertia: 0.08038531238550521
# Minibatch step 1723/103926: mean batch inertia: 0.0769666770236496, ewa inertia: 0.08037873346250865
# Minibatch step 1724/103926: mean batch inertia: 0.07393142779386058, ewa inertia: 0.08036632607680072
# Minibatch step 1725/103926: mean batch inertia: 0.08089809865263828, ewa inertia: 0.08036734943567285
# Minibatch step 1726/103926: mean batch inertia: 0.08277885475614474, ewa inertia: 0.08037199020783188
# Minibatch step 1727/103926: mean batch inertia: 0.08043648979950352, ewa inertia: 0.08037211433275367
# Minibatch step 1728/103926: mean batch inertia: 0.08047139966001055, ewa inertia: 0.08037230540037381
# Minibatch step 1729/103926: mean batch inertia: 0.07679616939686393, ewa inertia: 0.08036542337848437
# Minibatch step 1730/103926: mean batch inertia: 0.07779411365562974, ewa inertia: 0.08036047507400718
# Minibatch step 1731/103926: mean batch inertia: 0.07981656419958648, ewa inertia: 0.08035942835583428
# Minibatch step 1732/103926: mean batch inertia: 0.07915599539686047, ewa inertia: 0.08035711243385647
# Minibatch step 1733/103926: mean batch inertia: 0.07639483399553786, ewa inertia: 0.08034948730804531
# Minibatch step 1734/103926: mean batch inertia: 0.08130835497713466, ewa inertia: 0.08035133258134623
# Minibatch step 1735/103926: mean batch inertia: 0.07684396219755371, ewa inertia: 0.08034458289404911
# Minibatch step 1736/103926: mean batch inertia: 0.07878881793087623, ewa inertia: 0.0803415889339422
# Minibatch step 1737/103926: mean batch inertia: 0.07774926268004088, ewa inertia: 0.08033660018463111
# Minibatch step 1738/103926: mean batch inertia: 0.07769288066950006, ewa inertia: 0.08033151253260813
# Minibatch step 1739/103926: mean batch inertia: 0.07840291792125263, ewa inertia: 0.08032780108809981
# Minibatch step 1740/103926: mean batch inertia: 0.08083095741614328, ewa inertia: 0.08032876937701836
# Minibatch step 1741/103926: mean batch inertia: 0.07717036174004405, ewa inertia: 0.08032269124395179
# Minibatch step 1742/103926: mean batch inertia: 0.07852044348815247, ewa inertia: 0.08031922294506902
# Minibatch step 1743/103926: mean batch inertia: 0.07840912698162901, ewa inertia: 0.08031554709990585
# Minibatch step 1744/103926: mean batch inertia: 0.07985112604542083, ewa inertia: 0.08031465335429333
# Minibatch step 1745/103926: mean batch inertia: 0.07912782172465024, ewa inertia: 0.08031236938040467
# Minibatch step 1746/103926: mean batch inertia: 0.07552963420115161, ewa inertia: 0.08030316534337624
# Minibatch step 1747/103926: mean batch inertia: 0.07977746550208227, ewa inertia: 0.08030215367105407
# Minibatch step 1748/103926: mean batch inertia: 0.07847839053551371, ewa inertia: 0.08029864396733821
# Minibatch step 1749/103926: mean batch inertia: 0.07762225793588635, ewa inertia: 0.08029349345090511
# Minibatch step 1750/103926: mean batch inertia: 0.08235182529995648, ewa inertia: 0.08029745456559062
# Minibatch step 1751/103926: mean batch inertia: 0.07442689149568535, ewa inertia: 0.08028615708039688
# Minibatch step 1752/103926: mean batch inertia: 0.0805693776655815, ewa inertia: 0.08028670211846727
# Minibatch step 1753/103926: mean batch inertia: 0.07958221457433638, ewa inertia: 0.08028534638180211
# Minibatch step 1754/103926: mean batch inertia: 0.08045947243341414, ewa inertia: 0.08028568147512562
# Minibatch step 1755/103926: mean batch inertia: 0.08054214398199314, ewa inertia: 0.08028617501915872
# Minibatch step 1756/103926: mean batch inertia: 0.07646992046807224, ewa inertia: 0.0802788309060348
# Minibatch step 1757/103926: mean batch inertia: 0.08064737641144941, ewa inertia: 0.08027954014590516
# Minibatch step 1758/103926: mean batch inertia: 0.07819068862317266, ewa inertia: 0.08027552029825699
# Minibatch step 1759/103926: mean batch inertia: 0.07617292815651673, ewa inertia: 0.08026762514860519
# Minibatch step 1760/103926: mean batch inertia: 0.07450989389288949, ewa inertia: 0.08025654480029168
# Minibatch step 1761/103926: mean batch inertia: 0.08016659946040983, ewa inertia: 0.08025637170681948
# Minibatch step 1762/103926: mean batch inertia: 0.08214161592815435, ewa inertia: 0.08025999972655516
# Minibatch step 1763/103926: mean batch inertia: 0.07954577676654624, ewa inertia: 0.08025862525476776
# Minibatch step 1764/103926: mean batch inertia: 0.07832733253614124, ewa inertia: 0.08025490861794202
# Minibatch step 1765/103926: mean batch inertia: 0.07990609629501927, ewa inertia: 0.08025423735319166
# Minibatch step 1766/103926: mean batch inertia: 0.07523303510416987, ewa inertia: 0.0802445744030815
# Minibatch step 1767/103926: mean batch inertia: 0.0803310658943217, ewa inertia: 0.08024474084986521
# Minibatch step 1768/103926: mean batch inertia: 0.07991835000426656, ewa inertia: 0.08024411273366892
# Minibatch step 1769/103926: mean batch inertia: 0.07835255708678976, ewa inertia: 0.08024047256803928
# Minibatch step 1770/103926: mean batch inertia: 0.07921959727360141, ewa inertia: 0.08023850796543025
# Minibatch step 1771/103926: mean batch inertia: 0.07914273264123806, ewa inertia: 0.0802363992229888
# Minibatch step 1772/103926: mean batch inertia: 0.08206465442818008, ewa inertia: 0.08023991757137634
# Minibatch step 1773/103926: mean batch inertia: 0.07614255698432017, ewa inertia: 0.0802320324894831
# Minibatch step 1774/103926: mean batch inertia: 0.07796120558013765, ewa inertia: 0.08022766244301902
# Minibatch step 1775/103926: mean batch inertia: 0.07902759006152003, ewa inertia: 0.0802253529882359
# Minibatch step 1776/103926: mean batch inertia: 0.07773488630957383, ewa inertia: 0.08022056026050388
# Minibatch step 1777/103926: mean batch inertia: 0.0752885370909861, ewa inertia: 0.08021106892925178
# Minibatch step 1778/103926: mean batch inertia: 0.08000736465957864, ewa inertia: 0.08021067691473066
# Minibatch step 1779/103926: mean batch inertia: 0.08022007207146865, ewa inertia: 0.08021069499504815
# Minibatch step 1780/103926: mean batch inertia: 0.07927104147183923, ewa inertia: 0.08020888669801782
# Minibatch step 1781/103926: mean batch inertia: 0.07898941985531288, ewa inertia: 0.08020653991995996
# Minibatch step 1782/103926: mean batch inertia: 0.07952403370415044, ewa inertia: 0.08020522648481312
# Minibatch step 1783/103926: mean batch inertia: 0.07535447147795567, ewa inertia: 0.08019589154841676
# Minibatch step 1784/103926: mean batch inertia: 0.07900285175603615, ewa inertia: 0.08019359562735613
# Minibatch step 1785/103926: mean batch inertia: 0.08042191600567526, ewa inertia: 0.08019403501384476
# Minibatch step 1786/103926: mean batch inertia: 0.07965300192159813, ewa inertia: 0.08019299383376098
# Minibatch step 1787/103926: mean batch inertia: 0.07862305107196862, ewa inertia: 0.0801899725894791
# Minibatch step 1788/103926: mean batch inertia: 0.07998378767785407, ewa inertia: 0.08018957580113725
# Minibatch step 1789/103926: mean batch inertia: 0.07655166033624992, ewa inertia: 0.08018257488902521
# Minibatch step 1790/103926: mean batch inertia: 0.07996051518361529, ewa inertia: 0.0801821475507607
# Minibatch step 1791/103926: mean batch inertia: 0.0777263027373982, ewa inertia: 0.08017742145037021
# Minibatch step 1792/103926: mean batch inertia: 0.07899032594949604, ewa inertia: 0.08017513696867996
# Minibatch step 1793/103926: mean batch inertia: 0.08219253484208712, ewa inertia: 0.08017901930881213
# Minibatch step 1794/103926: mean batch inertia: 0.07787226022586673, ewa inertia: 0.08017458011341047
# Minibatch step 1795/103926: mean batch inertia: 0.0816966977566079, ewa inertia: 0.0801775093216197
# Minibatch step 1796/103926: mean batch inertia: 0.07745399305283858, ewa inertia: 0.080172268106364
# Minibatch step 1797/103926: mean batch inertia: 0.08122107622787189, ewa inertia: 0.08017428646373155
# Minibatch step 1798/103926: mean batch inertia: 0.0783710668613119, ewa inertia: 0.0801708162945984
# Minibatch step 1799/103926: mean batch inertia: 0.07737611495700765, ewa inertia: 0.08016543808869099
# Minibatch step 1800/103926: mean batch inertia: 0.08096238757390006, ewa inertia: 0.08016697176185013
# Minibatch step 1801/103926: mean batch inertia: 0.08139024749433546, ewa inertia: 0.08016932586984812
# Minibatch step 1802/103926: mean batch inertia: 0.08056669705409603, ewa inertia: 0.08017009058270735
# Minibatch step 1803/103926: mean batch inertia: 0.08219639533956086, ewa inertia: 0.08017399006350943
# Minibatch step 1804/103926: mean batch inertia: 0.07761289735603515, ewa inertia: 0.08016906142095881
# Minibatch step 1805/103926: mean batch inertia: 0.08152297350363535, ewa inertia: 0.08017166692941269
# Minibatch step 1806/103926: mean batch inertia: 0.08127371362099786, ewa inertia: 0.08017378774065903
# Minibatch step 1807/103926: mean batch inertia: 0.07935593222488159, ewa inertia: 0.08017221383531638
# Minibatch step 1808/103926: mean batch inertia: 0.0799085161721835, ewa inertia: 0.08017170636773459
# Minibatch step 1809/103926: mean batch inertia: 0.07836142097970675, ewa inertia: 0.08016822260099464
# Converged (lack of improvement in inertia) at step 1809/103926
# ✅ Clustering completed!
#    Number of clusters: 500
# 💾 Preparing data for saving...
# 💾 Saving models and processed data...
# ✅ All models and data saved successfully!
# 📁 Files saved to: /content/drive/MyDrive/ml project/movie_recommender_backend/ml_model2/artifacts
#    - tfidf_vectorizer.pkl
#    - svd_model.pkl
#    - kmeans_model.pkl
#    - movies_preprocessed.pkl
#    - models_trained.flag
#
# 📊 Dataset Statistics:
#    Total movies processed: 1039268
#    Number of clusters: 500
#    Unique clusters used: 456
#    Average movies per cluster: 2279.1
#
# ⏰ Total execution time: 12.57 minutes
#
# 🎉 Training completed successfully! You can now:
#    1. Download the .pkl files from Google Drive
#    2. Place them in your local movie_recommender_backend/ml_model/artifacts/ folder
#    3. Use test_recommendations.py to test the system
#    4. Run app.py to start the web server

# %%
import sys
import sklearn
import pandas as pd
import numpy as np

print(f"Python: {sys.version}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"Numpy: {np.__version__}")
# Out:
# Python: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# Scikit-learn: 1.6.1
# Pandas: 2.2.2
# Numpy: 2.0.2

# %%
import os

files = ['tfidf_vectorizer.pkl', 'svd_model.pkl', 'kmeans_model.pkl', 'movies_preprocessed.pkl']
artifacts_path = "/content/drive/MyDrive/ml project/movie_recommender_backend/ml_model/artifacts/"

print("File sizes in Colab:")
for file in files:
    full_path = os.path.join(artifacts_path, file)
    if os.path.exists(full_path):
        size = os.path.getsize(full_path)
        print(f"{file}: {size} bytes")
    else:
        print(f"{file}: MISSING")
# Out:
# File sizes in Colab:
# tfidf_vectorizer.pkl: 673086 bytes
# svd_model.pkl: 115999872 bytes
# kmeans_model.pkl: 2835425 bytes
# movies_preprocessed.pkl: 141584151 bytes

# %%
# In Colab, compress the artifacts folder first
# !cd "/content/drive/MyDrive/ml project/movie_recommender_backend/ml_model/" && zip -r artifacts.zip artifacts/

# Then download the zip file from Google Drive
# Extract locally instead of individual file downloads
# Out:
#   adding: artifacts/ (stored 0%)
#   adding: artifacts/tfidf_vectorizer.pkl (deflated 0%)
#   adding: artifacts/svd_model.pkl (deflated 0%)
#   adding: artifacts/kmeans_model.pkl (deflated 0%)
#   adding: artifacts/movies_preprocessed.pkl (deflated 0%)
#   adding: artifacts/models_trained.flag (stored 0%)
